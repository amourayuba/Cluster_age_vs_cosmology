# %%
import numpy as np
from formation_time import *
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import matplotlib.lines as mlines
from astropy.cosmology import LambdaCDM
from matplotlib import ticker
from matplotlib.ticker import FixedLocator, FixedFormatter, FuncFormatter

# %%
params = {'legend.fontsize': 12,
          'legend.handlelength': 2}
plt.rcParams["figure.dpi"]= 150
plt.rcParams["font.family"] = "serif"
plt.rcParams.update(params)

# %% [markdown]
# # Probability distributions

# %%
omegas = [0.15,  0.3,  0.5]
sigmas = [0.6, 0.7, 0.75, 0.8, 0.85,  0.9, 1]
mass = [1e11, 1e13, 1e15]
#zs = np.linspace(0.06, 3, 100)
zs = np.linspace(0.015, 3, 100)
dz = zs[1]-zs[0]
colors = ['black', 'green',  'blue']
save=False
fig, axs = plt.subplots(1,2, figsize=[12,5])
for i in range(len(mass)):
    if save:
        res2 = proba(mass[i], zs, acc=1000000, frac=0.5, zi=0.01, sig8=0.8, om0=0.3, ol0=0.7, model='SC', colos=True)
        res = proba(mass[i], zs, acc=1000000, frac=0.5, zi=0.01, sig8=0.8, om0=0.3, ol0=0.7, model='EC', colos=True)
        #res2 = new_proba(mass[i], zs, acc=5000, frac=0.5, zi=0.05, sig8=0.8, om0=0.3, ol0=0.7, model='SC', colos=True)
        res3 = proba(mass[i], zs, acc=1000000, frac=0.5, zi=0.01, sig8=0.8, om0=0.3, ol0=0.7, model='sheth2002', colos=True, alpha=0.615, beta=0.485, a=0.7)
        np.save('./data/pofz_zi_001_M_{:2.1e}_SC'.format(mass[i]), np.array(res2))
        np.save('./data/pofz_zi_001_M_{:2.1e}_zhang'.format(mass[i]), np.array(res))
        np.save('./data/pofz_zi_001_M_{:2.1e}_sheth'.format(mass[i]), np.array(res3))
    else:
        res2 = np.load('./data/pofz_zi_001_M_{:2.1e}_SC.npy'.format(mass[i]))
        res = np.load('./data/pofz_zi_001_M_{:2.1e}_zhang.npy'.format(mass[i]))
        res3 = np.load('./data/pofz_zi_001_M_{:2.1e}_sheth.npy'.format(mass[i]))
    if i == 2:
        for k in range(40, len(res)):
            res[k] = 0.97*res[k-1]
    dpdz1 = (res[2:]-res[:-2])*0.5/dz
    dpdz2 = (res2[2:]-res2[:-2])*0.5/dz
    dpdz3 = (res3[2:]-res3[:-2])*0.5/dz
    if i ==0:
        axs[1].plot(zs, res, color=colors[i], linewidth=2)
        axs[1].plot(zs, res2, '--', color=colors[i], label='Sph Collapse')
        axs[1].plot(zs, res3, '-.', color=colors[i], label='Sheth 2002')
    else:
        axs[1].plot(zs, res, color=colors[i], linewidth=2)
        axs[1].plot(zs, res2, '--', color=colors[i])
        axs[1].plot(zs, res3, '-.', color=colors[i])
        axs[1].plot([], [], color=colors[i], label='$M/M_\odot$={:2.1e}'.format(mass[i]))
    axs[0].plot(zs[1:-1], -dpdz1,linewidth=2,  color=colors[i])
    axs[0].plot(zs[1:-1], -dpdz2, '--', linewidth=1.5, color=colors[i])
    axs[0].plot(zs[1:-1], -dpdz3, '-.', linewidth=1.5, color=colors[i])


axs[1].set_ylabel('P(z>$z_f$)', size=15)
axs[0].set_ylabel('dP/dz', size=15)

axs[0].set_xlabel('z', size=20)
axs[1].set_xlabel('z', size=20)

axs[1].legend()
plt.savefig('./figs/z50_prob_all.png', dpi=650, bbox_inches ='tight', facecolor='white',transparent=False)
plt.savefig('./figs/z50_prob_all.pdf', dpi=650, bbox_inches ='tight', facecolor='white',transparent=False)

# %% [markdown]
# ### At different cosmos

# %%
omgs = [0.2, 0.25, 0.3, 0.35, 0.4]
sigs = [0.7,0.8, 0.9, 1]
mass = 1e14
zf = np.linspace(0.05, 2, 1000)
fig, axs = plt.subplots(1,2, figsize=[12,5])
for i in range(len(omgs)):
    y1 = proba(mass, zf, om0=omgs[i], ol0=1-el, model='EC', colos=True)
    y2 = proba(mass, zf, s8=sigs[i], model='EC', colos=True)
    axs[0].plot(zf, y1, label = '$\Omega_m$ = '+str(omgs[i]))
    axs[1].plot(zf, y2, label = '$\sigma_8$ = '+str(sigs[i]))
for j in range(2):
    axs[j].set_xlabel('z', size=20)
    axs[j].legend()
axs[0].set_ylabel('P ($z_f>z$)', size=20)
#plt.title('SC')

# %% [markdown]
# ## Average z50

# %%
Mass = np.logspace(9, 15, 50)
s8 = [0.6, 0.8, 1]
oms = [0.15, 0.3, 0.5]
#for el in s8:
fig, axs = plt.subplots(1,2, figsize=[12,5])

for i in range(len(oms)):
    res1, res2 = [], []
    for ms in Mass:
        res1.append(average_formation(M=ms, z=0.15, frac=0.5, om0=oms[i], sig8=0.8, colos=True))
        res2.append(average_formation(M=ms, z=0.15, frac=0.5, om0=0.3, sig8=s8[i], colos=True))

    axs[0].plot(Mass, res1, label='$\Omega_m=$'+str(oms[i]), linewidth=2.5)
    axs[1].plot(Mass, res2, label='$\sigma_8_m=$'+str(s8[i]), linewidth=2.5)
for j in range(2):
    axs[j].set_xlabel('Mass [$h^{-1}M_\odot$]', size = 15)
    axs[j].set_xscale('log')
    axs[j].set_legend(fontsize='x-large')

axs[0].set_ylabel('Average $z_{50}$', size = 15)
#plt.savefig('median_omega_mass.png', dpi=150, bbox_inches ='tight')
plt.show()

# %% [markdown]
# ## Median z50

# %%
Mass = np.logspace(9, 15, 50)
s8 = [0.6, 0.8, 1]
oms = [0.15, 0.3, 0.5]
save = False
colors = ['green', 'orange', 'blue']
fig, axs = plt.subplots(1,2, figsize=[12,5])
for i in range(len(oms)):
    if save:
        res_om, res_om2, res_s8, res_s82 = [], [], [], []
        for ms in Mass:
            res_om.append(median_formation(M=ms, z=0.15, frac=0.5, om0=oms[i], sig8=0.8, colos=True, outc=False))
            res_om2.append(median_formation(M=ms, z=0.15, frac=0.5, om0=oms[i], sig8=0.8, colos=True, model='SC', outc=False))
            
            res_s8.append(median_formation(M=ms, z=0.15, frac=0.5, om0=0.3, sig8=s8[i], colos=True, outc=False))
            res_s82.append(median_formation(M=ms, z=0.15, frac=0.5, om0=0.3, sig8=s8[i], colos=True, model='SC', outc=False))
    
        np.savetxt('./data/med_EC_om{:2.1f}.txt'.format(oms[i]),np.array(res_om))
        np.savetxt('./data/med_SC_om{:2.1f}.txt'.format(oms[i]),np.array(res_om22))
        
        np.savetxt('./data/med_EC_s8{:2.1f}.txt'.format(s8[i]),np.array(res_s8))
        np.savetxt('./data/med_SC_s8{:2.1f}.txt'.format(s8[i]),np.array(res_s82))

    else:
        res_om = np.loadtxt('./data/med_EC_om{:2.1f}.txt'.format(oms[i]))
        res_om2 = np.loadtxt('./data/med_SC_om{:2.1f}.txt'.format(oms[i]))
    
        res_s8 = np.loadtxt('./data/med_EC_s8{:2.1f}.txt'.format(s8[i]))
        res_s82 = np.loadtxt('./data/med_SC_s8{:2.1f}.txt'.format(s8[i]))
    
    axs[0].plot(Mass, res_om, label='$\Omega_m=$'+str(oms[i]), color = colors[i], linewidth=2)
    axs[0].plot(Mass, res_om2, '--', linewidth=1.5, color=colors[i])

    axs[1].plot(Mass, res_s8, label='$\sigma_8=$'+str(s8[i]), color = colors[i], linewidth=2)
    axs[1].plot(Mass, res_s82, '--', linewidth=1.5, color=colors[i])


for j in range(2):
    axs[j].set_xlabel('Mass [$h^{-1}M_\odot$]', size = 15)
    axs[j].set_xscale('log')
    axs[j].set_legend(fontsize='x-large')

axs[0].set_ylabel('Median $z_{50}$', size = 15)
plt.savefig('./figs/median_mass.pdf', dpi=650, bbox_inches ='tight')
plt.show()

# %% [markdown]
# ## Cosmology vs AGE

# %%
Mass = np.logspace(11, 15, 5)
sze = 25
save = True
omv = np.linspace(0.15, 0.5, sze)
s8 = np.linspace(0.6, 1.1, sze)
x = np.array([omv]*sze).transpose()
y = np.array([s8]*sze)
for ms in Mass:
    if save:
        nom = np.zeros((sze,sze))
        for i in range(sze):
            for j in range(sze):
                nom[i,j] = median_formation(M=ms, z=0.01, frac=0.5, om0=omv[i], sig8= s8[j], colos=True, outc=False)
        np.savetxt('./data/median_om_s8_'+str(int(np.log10(ms)))+'.txt', nom)
    else:
        nom = np.loadtxt('./data/median_om_s8_'+str(int(np.log10(ms)))+'.txt')
    plt.contourf(x, y, nom, levels=60, cmap='turbo')
    plt.annotate('log M='+str(round(np.log10(ms),2)),(0.3, 0.8), size=15)
    plt.title('AGE',  size=30)
    plt.xlabel('$\Omega_m$', size = 30)
    plt.ylabel('$\sigma_8$', size = 30)
    plt.colorbar()
    plt.savefig('./figs/new_median_om_s8_'+str(int(np.log10(ms)))+'.pdf', dpi=650, bbox_inches ='tight',facecolor='white')
    plt.savefig('./figs/new_median_om_s8_'+str(int(np.log10(ms)))+'.png', dpi=650, bbox_inches ='tight',facecolor='white')

    plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In [7], line 13
#      11     for i in range(sze):
#      12         for j in range(sze):
# ---> 13             nom[i,j] = median_formation(M=ms, z=0.01, frac=0.5, om0=omv[i], sig8= s8[j], colos=True, outc=False)
#      14     np.savetxt('./data/median_om_s8_'+str(int(np.log10(ms)))+'.txt', nom)
#      15 else:
#
# File ~/asus_fedora/PycharmProjects/halo_project/formation_time.py:244, in median_formation(M, z, frac, acc, nzeds, sig8, h, kmax, window, prec, om0, ol0, omb, camb, colos, outc)
#     242 res = []
#     243 for red in zs:
# --> 244     res.append(proba(M, red, frac, acc, z, sig8, h, kmax, window, prec, om0, ol0, omb, camb, 'EC', colos))
#     245 res = np.array(res)
#     246 zf = np.max(zs[res > 0.5])
#
# File ~/asus_fedora/PycharmProjects/halo_project/formation_time.py:135, in proba(M, zf, frac, acc, zi, sig8, h, kmax, window, prec, om0, ol0, omb, camb, model, colos, alpha, beta, a, order)
#     113 def proba(M, zf, frac=0.5, acc=1000, zi=0.0, sig8=sigma8, h=h, kmax=30, window='TopHat', prec=300, om0=om,
#     114               ol0=oml, omb=omb, camb=False, model='EC', colos=False, alpha=0.615, beta=0.485, a=0.7, order=3):
#     115     """
#     116      Probability density of a halo of mass M at redshift zi has had a fraction frac of its mass at z=zf.
#     117      :param M: float. mass of the halo considered
#    (...)
#     133      :return: Probability density function of redshift at which halos had x fraction of their mass
#     134      """
# --> 135     S0 = sigma(M, sig8, h, kmax, window, 'M', prec, om0, ol0, omb, camb, colos) ** 2  # variance of the field at mass M
#     136     w0 = delta_c(zi, om0, ol0)  # critical density at observed redshift
#     137     if type(zf) == np.ndarray: # for probability distribution. This is to have a parallel version with no for loops
#
# File ~/asus_fedora/PycharmProjects/halo_project/fluctuation_rms.py:215, in sigma(x, sig8, h, kmax, window, xin, prec, om0, ol0, omb, camb, Colos)
#     213 if window == 'TopHat':
#     214     R = (3 * x / (4 * np.pi * rho_m(0, om0))) ** (1 / 3)
# --> 215     return sigma_R(R, sig8, h, omb, om0, ol0, ns, kmax, prec, W_th, camb, Colos=Colos)
#     216 elif window == 'Gauss':
#     217     R = (x / rho_m(0, om0)) ** (1 / 3) / np.sqrt(np.pi)
#
# File ~/asus_fedora/PycharmProjects/halo_project/fluctuation_rms.py:123, in sigma_R(R, sig8, h, omb, om0, ol0, ns, kmax, prec, window, camb, test, Colos)
#     121 if Colos:
#     122     my_cosmo = {'flat': True, 'H0': 100 * h, 'Om0': om0, 'Ode0': ol0, 'Ob0': omb, 'sigma8': sig8, 'ns': ns}
# --> 123     cosmo = cosmology.setCosmology('my_cosmo', my_cosmo)
#     124     return cosmo.sigma(R, 0.0)
#     125 else:
#
# File ~/.local/lib/python3.11/site-packages/colossus/cosmology/cosmology.py:3138, in setCosmology(cosmo_name, params, **kwargs)
#    3135 		raise Exception('Invalid cosmology (%s).' % (cosmo_name))
#    3137 param_dict['name'] = cosmo_name
# -> 3138 cosmo = Cosmology(**(param_dict))
#    3139 setCurrent(cosmo)
#    3141 return cosmo
#
# File ~/.local/lib/python3.11/site-packages/colossus/cosmology/cosmology.py:565, in Cosmology.__init__(self, name, flat, Om0, Ode0, Ob0, H0, sigma8, ns, de_model, w0, wa, wz_function, relspecies, Tcmb0, Neff, power_law, power_law_n, interpolation, persistence, print_info, print_warnings)
#     562 self.print_warnings = print_warnings
#     564 # Create a storage object
# --> 565 self.storageUser = storage.StorageUser('cosmology', persistence, self.getName,
#     566 							self._getHashableString, self._deriveParameters)
#     568 # Lookup table for functions of z. This table runs from the future (a = 200.0) to
#     569 # a = 0.005. Due to some interpolation errors at the extrema of the range, the table
#     570 # runs to slightly lower and higher z than the interpolation is allowed for.
#    (...)
#     574 # otherwise lead to a crash because np.exp() overflows. A similar situation could easily
#     575 # occur for user-defined models.
#     576 if de_model in ['lambda', 'w0']:
#
# File ~/.local/lib/python3.11/site-packages/colossus/utils/storage.py:145, in StorageUser.__init__(self, module, persistence, func_name, func_hashstring, func_changed)
#     142 if self.persistence_read or self.persistence_write:
#     143 	self.cache_dir = getCacheDir(module = self.module)
# --> 145 self.resetStorage()
#     147 return
#
# File ~/.local/lib/python3.11/site-packages/colossus/utils/storage.py:224, in StorageUser.resetStorage(self)
#     222 try:
#     223 	input_file = open(filename_pickle, 'rb')
# --> 224 	self.storage_pers = pickle.load(input_file)
#     226 	# Check if a version was stored with this file. If not, assume it is old.
#     227 	if 'colossus_version' in self.storage_pers:
#
# File ~/.local/lib/python3.11/site-packages/numpy/core/numeric.py:1875, in _frombuffer(buf, dtype, shape, order)
#    1874 def _frombuffer(buf, dtype, shape, order):
# -> 1875     return frombuffer(buf, dtype=dtype).reshape(shape, order=order)
#
# KeyboardInterrupt:

# %% [markdown]
# # z50 and HMF

# %%
masses = [5e13, 5e14, 5e15]
#Mass = np.logspace(13, 15, 3)
sze = 40
#for ms in Mass: 
omv = np.linspace(0.15, 0.5, sze)
s8 = np.linspace(0.6, 1.1, sze)
nom = np.zeros((sze,sze))
nom2 = np.zeros((sze,sze))
x = np.array([omv]*sze).transpose()
y = np.array([s8]*sze)
save=False
for mass in masses:
    for red in zs:
        if save:
            for i in range(sze):
                for j in range(sze):
                    cosmo = LambdaCDM(H0=100*h, Om0=omv[i], Ode0=1-omv[i], Ob0=omb)
                    vol = cosmo.differential_comoving_volume(red).value*h**3
                    nom[i,j] = median_formation(M=mass, z=0.01+red, acc=1000, frac=0.5, om0=omv[i], model='EC', ol0=1-omv[i], sig8=s8[j], colos=False, outc=False)
                    nom2[i,j] = np.log10(vol*hmf(M=mass, z=red, sig8=s8[j], om0=omv[i], ol0=1-omv[i],
                                                              kmax=5, prec=100, camb=False, model='sheth', out='dndlnM'))
            np.savetxt('./data/n_z50_cross_z_{:1.0f}_M_{:2.0e}.txt'.format(red, mass), nom)
            np.savetxt('./data/n_hmf_cross_z_{:1.0f}_M_{:2.0e}.txt'.format(red, mass), nom2)
        else:
            nom = np.loadtxt('./data/n_z50_cross_z_{:1.0f}_M_{:2.0e}.txt'.format(red, mass))
            nom2 = np.loadtxt('./data/n_hmf_cross_z_{:1.0f}_M_{:2.0e}.txt'.format(red, mass))
        plt.contour(x, y, nom, levels=20, linestyles='dashed', cmap='gnuplot', alpha=1)
        plt.colorbar()
        plt.contourf(x, y, nom2, levels=40, cmap = 'turbo', alpha=0.7)

        plt.title('z={:2.1f}, M={:2.1e}$M_\odot/h$'.format(red, mass), size=15)
        plt.xlabel('$\Omega_m$', size = 15)
        plt.ylabel('$\sigma_8$', size = 15)

        plt.savefig('./figs/n_z50_hmf_cross_z_{:1.0f}_M_{:2.0e}.pdf'.format(red, mass), dpi=650, bbox_inches='tight', facecolor='white',transparent=False)
        plt.savefig('./figs/n_z50_hmf_cross_z_{:1.0f}_M_{:2.0e}.png'.format(red, mass), dpi=650, bbox_inches='tight', facecolor='white',transparent=False)        
        plt.show()
